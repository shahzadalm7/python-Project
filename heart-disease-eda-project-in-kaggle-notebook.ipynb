# %%
import os
import numpy as np 
import pandas as pd 
import seaborn as sns



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/heart-disease-dataset/documentation.pdf
# /kaggle/input/heart-disease-dataset/heart_statlog_cleveland_hungary_final.csv

# %%
df = pd.read_csv("/kaggle/input/heart-disease-dataset/heart_statlog_cleveland_hungary_final.csv")

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
df['age']
# Out:
# 0       40
# 1       49
# 2       37
# 3       48
# 4       54
#         ..
# 1185    45
# 1186    68
# 1187    57
# 1188    57
# 1189    38
# Name: age, Length: 1190, dtype: int64

# %% [markdown]
# ## Ditrubution Plot for Numerical Columns

# %%
sns.displot(df['age'] ,kde = True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(df['age'] ,kde = True , hist = True ,rug =True , color = 'blue')
# Out:
# /tmp/ipykernel_33/84890760.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'] ,kde = True , hist = True ,rug =True , color = 'blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
sns.distplot(df['resting bp s'] ,kde= True ,color ='blue')
# Out:
# /tmp/ipykernel_33/350011364.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['resting bp s'] ,kde= True ,color ='blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='resting bp s', ylabel='Density'>

# %%
sns.distplot(df['cholesterol'] ,kde= True ,color ='blue')
# Out:
# /tmp/ipykernel_33/513889965.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cholesterol'] ,kde= True ,color ='blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='cholesterol', ylabel='Density'>

# %% [markdown]
# # Pie Chart for categorical columns

# %%
df.groupby('sex').size() # 0 for female , 1 = for male .
# Out:
# sex
# 0    281
# 1    909
# dtype: int64

# %%
df.groupby('sex').size().plot(kind = 'pie' ,autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('sex').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df.groupby('chest pain type').size().plot(kind = 'pie' ,autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.015096         0.149055      0.257692
# sex                  0.015096  1.000000         0.138405     -0.006443
# chest pain type      0.149055  0.138405         1.000000      0.009466
# resting bp s         0.257692 -0.006443         0.009466      1.000000
# cholesterol         -0.046472 -0.208441        -0.109396      0.099037
# fasting blood sugar  0.178923  0.110961         0.076492      0.088235
# resting ecg          0.194595 -0.022225         0.035705      0.095860
# max heart rate      -0.368676 -0.181837        -0.337491     -0.101357
# exercise angina      0.188095  0.194380         0.403428      0.142435
# oldpeak              0.245093  0.096390         0.224106      0.176111
# ST slope             0.237749  0.127913         0.276949      0.089384
# target               0.262029  0.311267         0.460127      0.121415
#
# ...

# %%
df.groupby('chest pain type').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='chest pain type'>

# %%
df.groupby('resting ecg').size().plot(kind = 'pie' ,autopct = '%.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(df['age'])
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
sns.violinplot(y = df['age'] , x = df['target']) # target = heart disease
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.violinplot(y = df['chest pain type'] , x = df['target'])
# Out:
# <Axes: xlabel='target', ylabel='chest pain type'>

# %% [markdown]
# # correlation
# ### heatMap

# %%
df.corr()
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.015096         0.149055      0.257692
# sex                  0.015096  1.000000         0.138405     -0.006443
# chest pain type      0.149055  0.138405         1.000000      0.009466
# resting bp s         0.257692 -0.006443         0.009466      1.000000
# cholesterol         -0.046472 -0.208441        -0.109396      0.099037
# fasting blood sugar  0.178923  0.110961         0.076492      0.088235
# resting ecg          0.194595 -0.022225         0.035705      0.095860
# max heart rate      -0.368676 -0.181837        -0.337491     -0.101357
# exercise angina      0.188095  0.194380         0.403428      0.142435
# oldpeak              0.245093  0.096390         0.224106      0.176111
# ST slope             0.237749  0.127913         0.276949      0.089384
# target               0.262029  0.311267         0.460127      0.121415
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
## join plot (correlation)

sns.jointplot(x = 'age' , y = 'max heart rate' ,data =df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x = 'age' , y = 'max heart rate' ,data =df ,kind ='reg') 
 
    #jointplot with regration
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x = 'target' , y = 'oldpeak' ,data =df ,kind ='reg')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## pair plot

# %%
sns.pairplot(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
